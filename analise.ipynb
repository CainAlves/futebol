# %% [markdown]
# Analisando dados de Futebol

# %%
# Importando bibliotecas necessarias 
import basedosdados as bd
import pandas as pd 

# Para carregar o dado direto no pandas
df = bd.read_table(dataset_id='mundo_transfermarkt_competicoes',
table_id='brasileirao_serie_a',
billing_project_id="futebol-394512")
# Out:
# Downloading: 100%|██████████| 7890/7890 [00:03<00:00, 2428.83rows/s]

# %%
df.head()
# Out:
#    ano_campeonato        data  rodada estadio                      arbitro  \
# 0            2007  2007-07-07      10    None     Sergio da Silva Carvalho
# 1            2007  2007-07-22      13    None           Antonio Hora Filho
# 2            2007  2007-07-27      14    None  Luiz Alberto Sardinha Bites
# 3            2007  2007-08-02      16    None     Lourival Dias Lima Filho
# 4            2007  2007-07-20      12    None     Leonardo Gaciba da Silva
#
#    publico  publico_max    time_man     time_vis tecnico_man  ...  \
# 0    24923         <NA>    Botafogo  Atlético-PR        None  ...
# 1    10171         <NA>  Fluminense     Goiás EC        None  ...
# 2        0         <NA>    Botafogo    Juventude        None  ...
# 3    13314         <NA>    Botafogo   América-RN        None  ...
# 4    45000         <NA>    Flamengo       Paraná  Ney Franco  ...
#
#   chutes_bola_parada_man  chutes_bola_parada_vis  defesas_man  defesas_vis  \
# 0                   <NA>                    <NA>         <NA>         <NA>
# 1                   <NA>                    <NA>         <NA>         <NA>
# 2                   <NA>                    <NA>         <NA>         <NA>
# 3                   <NA>                    <NA>         <NA>         <NA>
# 4                   <NA>                    <NA>         <NA>         <NA>
#
#    impedimentos_man  impedimentos_vis  chutes_man  chutes_vis  \
# 0              <NA>              <NA>        <NA>        <NA>
# 1              <NA>              <NA>        <NA>        <NA>
# 2              <NA>              <NA>        <NA>        <NA>
# 3              <NA>              <NA>        <NA>        <NA>
# 4              <NA>              <NA>        <NA>        <NA>
#
#    chutes_fora_man  chutes_fora_vis
# 0             <NA>             <NA>
# 1             <NA>             <NA>
# 2             <NA>             <NA>
# 3             <NA>             <NA>
# 4             <NA>             <NA>
#
# [5 rows x 35 columns]

# %%
# Analisando a tabela extraida do site basedosdados.org 
resumo = df.describe()
print(resumo)
print(df.columns)
# Out:
#        ano_campeonato     rodada       publico   publico_max  colocacao_man  \
# count          7890.0     7890.0        6179.0        3637.0         6180.0
# mean      2012.423574   19.32256  15200.864379  43695.291174      10.643042
# std          5.938016  11.013561  13464.552666  19822.444624       5.759806
# min            2003.0        1.0           0.0        5000.0            1.0
# 25%            2007.0       10.0        5524.5       24584.0            6.0
# 50%            2012.0       19.0       12064.0       43600.0           11.0
# 75%            2018.0       29.0       21204.0       57483.0           16.0
# max            2023.0       38.0       82044.0       87101.0           20.0
#
#        colocacao_vis  valor_equipe_titular_man  valor_equipe_titular_vis  \
# count         6180.0                    5792.0                    5792.0
# mean       10.356958           18291679.903315           17831222.375691
# std         5.770136           14700869.339698            14027418.35279
# min              1.0                   50000.0                   50000.0
# 25%              5.0                 7550000.0                 7480000.0
# 50%             10.0                14000000.0                13550000.0
# 75%             15.0                25550000.0                24850000.0
# max             20.0               100500000.0                96000000.0
#
#        idade_media_titular_man  idade_media_titular_vis  ...  \
# count              5790.000000              5790.000000  ...
# mean                 27.212729                27.108791  ...
# std                   1.580528                 1.618188  ...
# min                  20.400000                20.500000  ...
# 25%                  26.200000                26.000000  ...
# 50%                  27.200000                27.100000  ...
# 75%                  28.300000                28.200000  ...
# max                  32.900000                32.300000  ...
#
#        chutes_bola_parada_man  chutes_bola_parada_vis  defesas_man  \
# count                  1601.0                  1601.0       1601.0
# mean                14.034354               14.341037     2.806996
# std                   4.46158                4.448019         1.86
# min                       0.0                     0.0          0.0
# 25%                      11.0                    11.0          1.0
# 50%                      14.0                    14.0          3.0
# 75%                      17.0                    17.0          4.0
# max                      30.0                    30.0         12.0
#
#        defesas_vis  impedimentos_man  impedimentos_vis  chutes_man  \
# count       1601.0            1601.0            1601.0      1601.0
# mean      3.518426          1.473454          1.394129   12.564647
# std       2.193414          1.375936          1.290907    6.246777
# min            0.0               0.0               0.0         0.0
# 25%            2.0               0.0               0.0         8.0
# 50%            3.0               1.0               1.0        12.0
# 75%            5.0               2.0               2.0        17.0
# max           13.0               8.0               8.0        37.0
#
#        chutes_vis  chutes_fora_man  chutes_fora_vis
# count      1601.0           1601.0           1601.0
# mean     9.860712         5.951905         4.667708
# std      5.319536         2.827907         2.558713
# min           0.0              0.0              0.0
# 25%           6.0              4.0              3.0
# 50%          10.0              6.0              4.0
# 75%          13.0              8.0              6.0
# max          31.0             21.0             14.0
#
# [8 rows x 28 columns]
# Index(['ano_campeonato', 'data', 'rodada', 'estadio', 'arbitro', 'publico',
#        'publico_max', 'time_man', 'time_vis', 'tecnico_man', 'tecnico_vis',
#        'colocacao_man', 'colocacao_vis', 'valor_equipe_titular_man',
#        'valor_equipe_titular_vis', 'idade_media_titular_man',
#        'idade_media_titular_vis', 'gols_man', 'gols_vis', 'gols_1_tempo_man',
#        'gols_1_tempo_vis', 'escanteios_man', 'escanteios_vis', 'faltas_man',
#        'faltas_vis', 'chutes_bola_parada_man', 'chutes_bola_parada_vis',
#        'defesas_man', 'defesas_vis', 'impedimentos_man', 'impedimentos_vis',
#        'chutes_man', 'chutes_vis', 'chutes_fora_man', 'chutes_fora_vis'],
#       dtype='object')

# %%
# Limpando a base para analisar somente o ano corrente 
df_2023 = df[df['ano_campeonato'] == 2023]
df_2023.head()
# Out:
#       ano_campeonato        data  rodada                estadio  \
# 4560            2023  2023-04-24       2  Estádio Serra Dourada
# 4561            2023  2023-05-07       4  Estádio Serra Dourada
# 4562            2023  2023-05-14       6  Estádio Serra Dourada
# 4563            2023  2023-06-04       9  Estádio Serra Dourada
# 4564            2023  2023-06-11      10  Estádio Serra Dourada
#
#                              arbitro  publico  publico_max time_man  \
# 4560           Bruno Arleu de Araújo    10162        14525    Goiás
# 4561  Wagner do Nascimento Magalhães    13789        14525    Goiás
# 4562            Rafael Rodrigo Klein     9092        14525    Goiás
# 4563      Marcelo de Lima Henrique       6987        14525    Goiás
# 4564            Leandro Pedro Vuaden    10260        14525    Goiás
#
#          time_vis    tecnico_man  ... chutes_bola_parada_man  \
# 4560  Corinthians  Émerson Ávila  ...                     21
# 4561    Palmeiras  Émerson Ávila  ...                     29
# 4562     Botafogo  Émerson Ávila  ...                     18
# 4563    Cuiabá-MT  Émerson Ávila  ...                     14
# 4564   Fluminense  Émerson Ávila  ...                     23
#
#       chutes_bola_parada_vis  defesas_man  defesas_vis  impedimentos_man  \
# 4560                      20            1            4                 4
# 4561                      13            3            4                 1
# 4562                      20            1            2                 2
# 4563                      18            7            3                 2
# 4564                      15            2            7                 5
#
#       impedimentos_vis  chutes_man  chutes_vis  chutes_fora_man  \
# 4560                 1          18          10                6
# 4561                 1          15          16                7
# 4562                 2           7          17                2
# 4563                 1          11          15                7
# 4564                 1          22          14                9
#
#       chutes_fora_vis
# 4560                4
# 4561                5
# 4562               10
# 4563                2
# 4564                5
#
# [5 rows x 35 columns]

# %% [markdown]
# Quais times possues as maiores médias de público ?

# %%
media_publico = df_2023.groupby('time_man')['publico'].mean()
media_publico = media_publico.round(1)
media_publico = media_publico.sort_values(ascending=False)
print(media_publico)
# Out:
# time_man
# Flamengo         55673.7
# São Paulo        49359.6
# Corinthians      38877.2
# Palmeiras        37576.4
# Fortaleza        36774.4
# Fluminense       36179.0
# EC Bahia         36080.6
# Atlético-MG      33623.8
# Cruzeiro         28941.6
# Grêmio           27800.0
# Internacional    25112.4
# Athletico-PR     24836.0
# Vasco da Gama    24549.5
# Coritiba FC      23214.4
# Botafogo         20007.5
# Cuiabá-MT        12835.2
# Santos           10516.0
# Goiás            10058.0
# América-MG        5211.2
# RB Bragantino     4172.6
# Name: publico, dtype: Float64

# %% [markdown]
# Quais times fizeram mais gols dentro de casa? (Melhores ataques mandantes)
